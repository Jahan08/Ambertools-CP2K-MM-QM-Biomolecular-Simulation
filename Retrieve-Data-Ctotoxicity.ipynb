# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Ambertools-CP2K-MM-QM-Biomolecular-Simulation/blob/main/Retrieve-Data-Ctotoxicity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('HEPG2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0                                                 []  Homo sapiens
# 1                                                 []  Homo sapiens
# 2                                                 []  Homo sapiens
# 3  [{'xref_id': 'P11166', 'xref_name': None, 'xre...  Homo sapiens
#
#              pref_name  score  species_group_flag target_chembl_id  \
# 0                HepG2   19.0               False        CHEMBL395
# 1         HepG2 2.2.15   16.0               False    CHEMBL4296438
# 2           HepG2-CD81   16.0               False    CHEMBL4543887
# 3  Glucose transporter   14.0               False       CHEMBL2535
#
#                                    target_components     target_type  tax_id
# 0                                                 []       CELL-LINE    9606
# 1                                                 []       CELL-LINE    9606
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL395'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="CC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#      activity_comment  activity_id  \
# 0                None       514289
# 1                None       517966
# 2                None       521988
# 3                None       523203
# 4                None       527095
# ...               ...          ...
# 2941             None     23304389
# 2942             None     23304390
# 2943             None     23304391
# 2944             None     23304392
# 2945             None     24374389
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL615274
# 1                                                    []    CHEMBL615274
# 2                                                    []    CHEMBL615274
# 3                                                    []    CHEMBL615274
# 4                                                    []    CHEMBL615274
# ...                                                 ...             ...
# ...

# %%
df = pd.read_csv('/content/bioactivity_data_UO-31.csv', header = 0)
# Out:
# <ipython-input-176-0c86e62881e9>:1: DtypeWarning: Columns (15,25,28,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/bioactivity_data_UO-31.csv', header = 0)

# %%
# considering nM unit for MIC
#df = df[(df['standard_type'] == 'GI50')]
#df = df[(df['standard_type'] == 'IC50')]
#df = df[(df['standard_type'] == 'EC50')]
df = df[(df['standard_units'] == 'nM')]
df = df[(df['relation'] == '=')]
df = df[df.canonical_smiles.notna()]
df = df[df.standard_value.notna()]
df
# Out:
#      activity_comment  activity_id  \
# 3                None       523203
# 4                None       527095
# 5                None       527107
# 12               None       544344
# 13               None       544357
# ...               ...          ...
# 2873             None     23245079
# 2875             None     23245081
# 2876             None     23245082
# 2892             None     23300528
# 2898             None     23300534
#
#                                     activity_properties assay_chembl_id  \
# 3                                                    []    CHEMBL615274
# 4                                                    []    CHEMBL615274
# 5                                                    []    CHEMBL615274
# 12                                                   []    CHEMBL615274
# 13                                                   []    CHEMBL615274
# ...                                                 ...             ...
# ...

# %%
fix = []

for i in df.standard_value:
    fix.append(float(i))

STATUS = []

for i in fix:
    if i < 20000:
        STATUS.append("Yes") #active
        
    elif 50000 <= i <= 100000:
        STATUS.append("No") #inactive
        
    else:
        STATUS.append("IN") #intermediate     

df = df.drop('value', 1)
df['value'] = fix
df['Activity'] = STATUS
df
# Out:
# <ipython-input-19-12988964c194>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('value', 1)
#      activity_comment  activity_id  \
# 3                None       523203
# 4                None       527095
# 5                None       527107
# 12               None       544344
# 13               None       544357
# ...               ...          ...
# 2873             None     23245079
# 2875             None     23245081
# 2876             None     23245082
# 2892             None     23300528
# 2898             None     23300534
#
#                                     activity_properties assay_chembl_id  \
# 3                                                    []    CHEMBL615274
# 4                                                    []    CHEMBL615274
# 5                                                    []    CHEMBL615274
# ...

# %%
# considering nM unit for MIC
df = df[(df['Activity'] != 'IN')]
len(df)
# Out:
# 698

# %%
df.to_csv('/content/bioactivity_data_HEPG2_CC50.csv', index=False)
