# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/Ambertools-CP2K-MM-QM-Biomolecular-Simulation/blob/main/Cytotoxicity-data-preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_url = 'https://github.com/Jahan08/Ambertools-CP2K-MM-QM-Biomolecular-Simulation/raw/main/AD3C_Tox_CC50_230502_cellline_5.xlsx'
df = pd.read_excel(df_url)
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-16-757dc21393cb> in <cell line: 2>()
#       1 df_url = 'https://github.com/Jahan08/Ambertools-CP2K-MM-QM-Biomolecular-Simulation/raw/main/AD3C_Tox_CC50_230502_cellline_5.xlsx'
# ----> 2 df = pd.read_excel(df_url)
#       3 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
df = df[df.CC50_UM.notna()]
df = df[df.CELLLINE.notna()]
df
# Out:
#          OBJID_BATCH          LIBRARY                  SUPPLIER_ID  \
# 37     AB00683628_01  Kinase-LifeChem    Life Chemicals_F3249-0141
# 39     AB00683638_01  Kinase-LifeChem    Life Chemicals_F3250-0551
# 42     AB00126439_02  Kinase-LifeChem    Life Chemicals_F3110-1117
# 43     AB00682711_01  Kinase-LifeChem    Life Chemicals_F3110-1165
# 44     AB00682712_01  Kinase-LifeChem    Life Chemicals_F3110-1169
# ...              ...              ...                          ...
# 18029  AB01973690_01        AD3C_S107  SRI Repository_SRI-00047488
# 18030  AB01973691_01        AD3C_S107  SRI Repository_SRI-00047489
# 18031  AB01973692_01        AD3C_S107  SRI Repository_SRI-00047490
# 18032  AB01973693_01        AD3C_S107  SRI Repository_SRI-00047491
# 18033  AB01973694_01        AD3C_S107  SRI Repository_SRI-00047432
#
#                                                   Smiles  \
# 37      c1(ccc(c2c1O)cccn2)C(Nc(cc3)ccc3C(OCC)=O)c4cccs4
# ...

# %%
df.to_excel('/content/AD3C_Tox_CC50_230502_cellline_4_curated.xlsx', index=False)
